# %% [markdown]
# # RESELLER DIMENSION

# %%
import pandas as pd
from connection_script import connect_databases

# %%
db_op, db_etl = connect_databases()

# %% [markdown]
# ## Extraction

# %%
store = pd.read_sql_query('SELECT * FROM [Sales].[Store]', db_op)
store_demographics = pd.read_sql_query('SELECT * FROM [Sales].[vStoreWithDemographics]', db_op)
person_phone = pd.read_sql_query('SELECT * FROM [Person].[PersonPhone]', db_op)
sales_person = pd.read_sql_query('SELECT * FROM [Sales].[SalesPerson]', db_op)
dim_geography = pd.read_sql_query('SELECT * FROM "DimGeography"', db_etl)
address = pd.read_sql_query('SELECT AddressID, AddressLine1, AddressLine2 FROM [Person].[Address]', db_op)
business_entity_address = pd.read_sql_query('SELECT * FROM [Person].[BusinessEntityAddress]', db_op)

# %% [markdown]
# ## TRANSFORM

# %%
#Merging data frames
merged_df = store.merge(store_demographics, on='BusinessEntityID', how='inner')
merged_df = merged_df.merge(person_phone, left_on='SalesPersonID', right_on='BusinessEntityID', how='inner')
merged_df = merged_df.merge(sales_person, left_on='SalesPersonID', right_on='BusinessEntityID', how='inner')
merged_df = merged_df.merge(dim_geography, left_on='TerritoryID', right_on='GeographyKey', how='inner')
merged_df = merged_df.merge(business_entity_address, left_on='BusinessEntityID', right_on='BusinessEntityID', how='inner', suffixes=('_store', '_address'))
merged_df = merged_df.merge(address, left_on='AddressID', right_on='AddressID', how='inner')
merged_df.columns
# Out:
# Index(['BusinessEntityID_x', 'Name_x', 'SalesPersonID', 'Demographics',
#        'rowguid_x', 'ModifiedDate_x', 'Name_y', 'AnnualSales', 'AnnualRevenue',
#        'BankName', 'BusinessType', 'YearOpened', 'Specialty', 'SquareFeet',
#        'Brands', 'Internet', 'NumberEmployees', 'BusinessEntityID_y',
#        'PhoneNumber', 'PhoneNumberTypeID', 'ModifiedDate_y',
#        'BusinessEntityID', 'TerritoryID', 'SalesQuota', 'Bonus',
#        'CommissionPct', 'SalesYTD', 'SalesLastYear', 'rowguid_y',
#        'ModifiedDate_store', 'GeographyKey', 'City', 'StateProvinceCode',
#        'StateProvinceName', 'CountryRegionCode', 'EnglishCountryRegionName',
#        'PostalCode', 'SalesTerritoryID', 'AddressID', 'AddressTypeID',
#        'rowguid', 'ModifiedDate_address', 'AddressLine1', 'AddressLine2'],
#       dtype='object')

# %%
def generateAlternateKey(ind):
    l = len(str(ind))
    zeros = 8 - l
    alternateKey = 'AW' + '0'*zeros + str(ind)
    return alternateKey

# %%
merged_df = merged_df.reset_index(drop=False)
merged_df['index'] = merged_df['index'] + 1
merged_df.set_index('index', inplace=True)
merged_df['ResellerAlternateKey'] = merged_df.index.to_series().apply(generateAlternateKey)
merged_df[['BusinessEntityID', 'ResellerAlternateKey']]
# Out:
#        BusinessEntityID ResellerAlternateKey
# index
# 1                   279           AW00000001
# 2                   276           AW00000002
# 3                   277           AW00000003
# 4                   275           AW00000004
# 5                   286           AW00000005
# ...                 ...                  ...
# 697                 282           AW00000697
# 698                 281           AW00000698
# 699                 277           AW00000699
# 700                 277           AW00000700
# 701                 275           AW00000701
#
# [701 rows x 2 columns]

# %%
# Column Selection
result = merged_df[['ResellerAlternateKey', 'GeographyKey', 'PhoneNumber', 'BusinessType', 'Name_x', 'NumberEmployees', 'Specialty', 'AddressLine1', 'AddressLine2', 
           'AnnualSales', 'BankName', 'AnnualRevenue', 'YearOpened']]

#Renaming
# Create a copy of the DataFrame to avoid SettingWithCopyWarning
result = result.copy()

result = result.rename(columns={'PhoneNumber': 'Phone',
                        'Name_x': 'ResellerName',
                        'Specialty': 'ProductLine'})

result
# Out:
#       ResellerAlternateKey  GeographyKey                Phone BusinessType  \
# index
# 1               AW00000001             5         664-555-0112           BM
# 2               AW00000002             4         883-555-0116           BM
# 3               AW00000003             3         517-555-0117           BM
# 4               AW00000004             2         257-555-0154           BM
# 5               AW00000005             9  1 (11) 500 555-0190           BM
# ...                    ...           ...                  ...          ...
# 697             AW00000697             6         185-555-0169           BM
# 698             AW00000698             4         330-555-0120           BM
# 699             AW00000699             3         517-555-0117           BM
# 700             AW00000700             3         517-555-0117           BM
# 701             AW00000701             2         257-555-0154           BM
#
#                          ResellerName  NumberEmployees ProductLine  \
# index
# 1                Next-Door Bike Store               13    Mountain
# 2      Professional Sales and Service               14     Touring
# 3                      Riders Company               15        Road
# 4                  The Bike Mechanics               16    Mountain
# 5                   Nationwide Supply               17     Touring
# ...                               ...              ...         ...
# 697                       Retreat Inn                8        Road
# 698     Technical Parts Manufacturing                5     Touring
# 699           Totes & Baskets Company                2        Road
# 700                    World of Bikes               17    Mountain
# 701             A Bicycle Association               18     Touring
#
#                      AddressLine1 AddressLine2  AnnualSales  \
# index
# 1               8291 Crossbow Way         None     800000.0
# 2            2487 Riverside Drive         None     800000.0
# 3              80 Sunview Terrace         None     800000.0
# 4                 8154 Via Mexico         None     800000.0
# 5                34 Waterloo Road         None     800000.0
# ...                           ...          ...          ...
# 697    9100 Sheppard Avenue North         None     300000.0
# 698              5725 Glaze Drive         None     300000.0
# 699            80 Sunview Terrace         None     300000.0
# 700            80 Sunview Terrace         None     800000.0
# 701               8154 Via Mexico         None     800000.0
#
#                      BankName  AnnualRevenue  YearOpened
# index
# 1             United Security        80000.0        1996
# 2          International Bank        80000.0        1991
# 3      Primary Bank & Reserve        80000.0        1999
# 4      International Security        80000.0        1994
# 5               Guardian Bank        80000.0        1987
# ...                       ...            ...         ...
# 697    Primary Bank & Reserve        30000.0        1982
# 698    International Security        30000.0        1976
# 699             Guardian Bank        30000.0        1970
# 700    Primary Bank & Reserve        80000.0        1997
# 701    International Security        80000.0        1975
#
# [701 rows x 13 columns]

# %% [markdown]
# ## LOAD

# %%
db_op, db_etl = connect_databases()
result.to_sql('DimReseller', db_etl, if_exists='replace', index_label='ResellerKey')
# Out:
# 701

# %%
# Testing table creation
dim_reseller = pd.read_sql_query('SELECT * FROM "DimReseller"', db_etl)
dim_reseller
# Out:
#      ResellerKey ResellerAlternateKey  GeographyKey                Phone  \
# 0              1           AW00000001             5         664-555-0112
# 1              2           AW00000002             4         883-555-0116
# 2              3           AW00000003             3         517-555-0117
# 3              4           AW00000004             2         257-555-0154
# 4              5           AW00000005             9  1 (11) 500 555-0190
# ..           ...                  ...           ...                  ...
# 696          697           AW00000697             6         185-555-0169
# 697          698           AW00000698             4         330-555-0120
# 698          699           AW00000699             3         517-555-0117
# 699          700           AW00000700             3         517-555-0117
# 700          701           AW00000701             2         257-555-0154
#
#     BusinessType                    ResellerName  NumberEmployees ProductLine  \
# 0             BM            Next-Door Bike Store               13    Mountain
# 1             BM  Professional Sales and Service               14     Touring
# 2             BM                  Riders Company               15        Road
# 3             BM              The Bike Mechanics               16    Mountain
# 4             BM               Nationwide Supply               17     Touring
# ..           ...                             ...              ...         ...
# 696           BM                     Retreat Inn                8        Road
# 697           BM   Technical Parts Manufacturing                5     Touring
# 698           BM         Totes & Baskets Company                2        Road
# 699           BM                  World of Bikes               17    Mountain
# 700           BM           A Bicycle Association               18     Touring
#
#                    AddressLine1 AddressLine2  AnnualSales  \
# 0             8291 Crossbow Way         None     800000.0
# 1          2487 Riverside Drive         None     800000.0
# 2            80 Sunview Terrace         None     800000.0
# 3               8154 Via Mexico         None     800000.0
# 4              34 Waterloo Road         None     800000.0
# ..                          ...          ...          ...
# 696  9100 Sheppard Avenue North         None     300000.0
# 697            5725 Glaze Drive         None     300000.0
# 698          80 Sunview Terrace         None     300000.0
# 699          80 Sunview Terrace         None     800000.0
# 700             8154 Via Mexico         None     800000.0
#
#                    BankName  AnnualRevenue  YearOpened
# 0           United Security        80000.0        1996
# 1        International Bank        80000.0        1991
# 2    Primary Bank & Reserve        80000.0        1999
# 3    International Security        80000.0        1994
# 4             Guardian Bank        80000.0        1987
# ..                      ...            ...         ...
# 696  Primary Bank & Reserve        30000.0        1982
# 697  International Security        30000.0        1976
# 698           Guardian Bank        30000.0        1970
# 699  Primary Bank & Reserve        80000.0        1997
# 700  International Security        80000.0        1975
#
# [701 rows x 14 columns]
