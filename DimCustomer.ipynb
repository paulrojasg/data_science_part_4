# %% [markdown]
# # CUSTOMER DIMENSION

# %%
import pandas as pd
from connection_script import connect_databases

# %%
db_op, db_etl = connect_databases()

# %% [markdown]
# ## EXTRACT

# %%
# Load the required tables into pandas DataFrames
individual_customer = pd.read_sql_query('SELECT * FROM [Sales].[vIndividualCustomer]', db_op)
sales_customer = pd.read_sql_query('SELECT CustomerID,PersonID,AccountNumber  FROM [Sales].[Customer]', db_op)
person = pd.read_sql_query('SELECT * FROM [Person].[Person]', db_op)
person_phone = pd.read_sql_query('SELECT * FROM [Person].[PersonPhone]', db_op)
person_demographics = pd.read_sql_query('SELECT * FROM [Sales].[vPersonDemographics]', db_op)
dim_geography = pd.read_sql_query('SELECT * FROM "DimGeography"', db_etl)

# Merge the DataFrames
merged_df = individual_customer.merge(person, left_on='BusinessEntityID', right_on='BusinessEntityID')
merged_df = merged_df.merge(person_phone, left_on='BusinessEntityID', right_on='BusinessEntityID')
merged_df = merged_df.merge(person_demographics, left_on='BusinessEntityID', right_on='BusinessEntityID')
print(merged_df.columns)
merged_df = merged_df.merge(dim_geography, on=['City', 'PostalCode', 'StateProvinceName', 'StateProvinceName'])
merged_df = merged_df.merge(sales_customer, left_on='BusinessEntityID', right_on='PersonID')

# Select the desired columns
result = merged_df[['BusinessEntityID', 'CustomerID', 'AccountNumber','GeographyKey', 'Title_x','FirstName_x', 'MiddleName_x', 'LastName_x', 'NameStyle', 'BirthDate', 'MaritalStatus', 'Suffix_x', 'Gender',
                    'EmailAddress', 'YearlyIncome', 'TotalChildren', 'NumberChildrenAtHome', 'Education',
                    'Occupation', 'HomeOwnerFlag', 'NumberCarsOwned', 'AddressLine1', 'AddressLine2',
                    'PhoneNumber_x', 'DateFirstPurchase']]

result
# Out:
# Index(['BusinessEntityID', 'Title_x', 'FirstName_x', 'MiddleName_x',
#        'LastName_x', 'Suffix_x', 'PhoneNumber_x', 'PhoneNumberType',
#        'EmailAddress', 'EmailPromotion_x', 'AddressType', 'AddressLine1',
#        'AddressLine2', 'City', 'StateProvinceName', 'PostalCode',
#        'CountryRegionName', 'Demographics_x', 'PersonType', 'NameStyle',
#        'Title_y', 'FirstName_y', 'MiddleName_y', 'LastName_y', 'Suffix_y',
#        'EmailPromotion_y', 'AdditionalContactInfo', 'Demographics_y',
#        'rowguid', 'ModifiedDate_x', 'PhoneNumber_y', 'PhoneNumberTypeID',
#        'ModifiedDate_y', 'TotalPurchaseYTD', 'DateFirstPurchase', 'BirthDate',
#        'MaritalStatus', 'YearlyIncome', 'Gender', 'TotalChildren',
#        'NumberChildrenAtHome', 'Education', 'Occupation', 'HomeOwnerFlag',
#        'NumberCarsOwned'],
#       dtype='object')
#        BusinessEntityID  CustomerID AccountNumber  GeographyKey Title_x  \
# 0                  1699       11377    AW00011377           210     Mr.
# 1                  1700       11913    AW00011913            37     Ms.
# 2                  1701       11952    AW00011952            34     Ms.
# 3                  1702       20164    AW00020164           244     Ms.
# 4                  1703       20211    AW00020211            22     Mr.
# ...                 ...         ...           ...           ...     ...
# 18503             20773       19379    AW00019379           272    None
# 18504             20774       13933    AW00013933           380    None
# 18505             20775       24634    AW00024634           633    None
# 18506             20776       21127    AW00021127           145    None
# 18507             20777       27980    AW00027980             3    None
#
#       FirstName_x MiddleName_x  LastName_x  NameStyle  BirthDate  ...  \
# 0           David           R.    Robinett      False 1961-02-23  ...
# 1         Rebecca           A.    Robinson      False 1965-06-11  ...
# 2         Dorothy           B.    Robinson      False 1954-09-23  ...
# 3       Carol Ann           F.      Rockne      False 1943-07-15  ...
# 4           Scott           M.     Rodgers      False 1968-05-15  ...
# ...           ...          ...         ...        ...        ...  ...
# 18503     Crystal         None         Guo      False 1974-11-23  ...
# 18504    Isabella            F  Richardson      False 1961-06-12  ...
# 18505     Crystal            S          He      False 1940-04-05  ...
# 18506     Crystal         None       Zheng      False 1975-07-25  ...
# 18507     Crystal         None          Hu      False 1971-05-05  ...
#
#       TotalChildren NumberChildrenAtHome            Education      Occupation  \
# 0               4.0                  0.0      Graduate Degree        Clerical
# 1               3.0                  3.0           Bachelors     Professional
# 2               2.0                  0.0      Partial College  Skilled Manual
# 3               1.0                  0.0           Bachelors         Clerical
# 4               2.0                  2.0           Bachelors     Professional
# ...             ...                  ...                  ...             ...
# 18503           0.0                  0.0  Partial High School          Manual
# 18504           1.0                  0.0      Partial College  Skilled Manual
# 18505           3.0                  0.0           Bachelors       Management
# 18506           0.0                  0.0      Partial College        Clerical
# 18507           0.0                  0.0           Bachelors     Professional
#
#       HomeOwnerFlag  NumberCarsOwned            AddressLine1 AddressLine2  \
# 0              True              0.0        Pappelallee 6667         None
# 1              True              1.0      1861 Chinquapin Ct         None
# 2             False              2.0          4693 Mills Dr.         None
# 3              True              0.0     1312 Skycrest Drive         None
# 4              True              1.0    9860 Brookview Drive         None
# ...             ...              ...                     ...          ...
# 18503          True              2.0   988 Mt. Everest Court         None
# 18504          True              1.0       7413 Alpine Drive         None
# 18505          True              2.0        4764 East Avenue         None
# 18506          True              1.0  34334, rue Jean Mermoz         None
# 18507         False              4.0       6022 La Salle Ct.         None
#
#              PhoneNumber_x DateFirstPurchase
# 0             238-555-0100        2003-09-01
# 1             648-555-0100        2004-06-05
# 2             423-555-0100        2002-04-07
# 3             439-555-0100        2001-10-27
# 4             989-555-0100        2002-04-18
# ...                    ...               ...
# 18503  1 (11) 500 555-0171        2004-04-19
# 18504         910-555-0166        2003-08-30
# 18505         813-555-0148        2004-04-12
# 18506  1 (11) 500 555-0171        2004-02-15
# 18507  1 (11) 500 555-0126        2003-11-17
#
# [18508 rows x 25 columns]

# %%
merged_df.columns
# Out:
# Index(['BusinessEntityID', 'Title_x', 'FirstName_x', 'MiddleName_x',
#        'LastName_x', 'Suffix_x', 'PhoneNumber_x', 'PhoneNumberType',
#        'EmailAddress', 'EmailPromotion_x', 'AddressType', 'AddressLine1',
#        'AddressLine2', 'City', 'StateProvinceName', 'PostalCode',
#        'CountryRegionName', 'Demographics_x', 'PersonType', 'NameStyle',
#        'Title_y', 'FirstName_y', 'MiddleName_y', 'LastName_y', 'Suffix_y',
#        'EmailPromotion_y', 'AdditionalContactInfo', 'Demographics_y',
#        'rowguid', 'ModifiedDate_x', 'PhoneNumber_y', 'PhoneNumberTypeID',
#        'ModifiedDate_y', 'TotalPurchaseYTD', 'DateFirstPurchase', 'BirthDate',
#        'MaritalStatus', 'YearlyIncome', 'Gender', 'TotalChildren',
#        'NumberChildrenAtHome', 'Education', 'Occupation', 'HomeOwnerFlag',
#        'NumberCarsOwned', 'GeographyKey', 'StateProvinceCode',
#        'CountryRegionCode', 'EnglishCountryRegionName', 'SalesTerritoryID',
#        'CustomerID', 'PersonID', 'AccountNumber'],
#       dtype='object')

# %%
len(result)
# Out:
# 18508

# %% [markdown]
# ## TRANSFORM

# %%
result = result.drop_duplicates(subset=['BusinessEntityID'])

# %%
# Rename columns
result = result.rename(columns={'Education':'EnglishEducation', 'Occupation':'EnglishOccupation', 'HomeOwnerFlag':'HouseOwnerFlag'})

# %%
result = result.rename(columns={
    'CustomerID': 'CustomerKey',
    'AccountNumber': 'CustomerAlternateKey',
    'Title_x': 'Title',
    'FirstName_x': 'FirstName',
    'MiddleName_x': 'MiddleName',
    'LastName_x': 'LastName',
    'Suffix_x': 'Suffix',
    'PhoneNumber_x': 'Phone',
    'Education':'EnglishEducation',
    'Occupation':'EnglishOccupation',
    'HomeOwnerFlag':'HouseOwnerFlag'
})

# %%
result = result[['CustomerKey', 'GeographyKey', 'CustomerAlternateKey','Title', 'FirstName', 'MiddleName', 'LastName', 'NameStyle', 'BirthDate', 
                       'MaritalStatus', 'Suffix', 'Gender', 'EmailAddress', 'YearlyIncome', 
                       'TotalChildren', 'NumberChildrenAtHome', 'EnglishEducation', 'EnglishOccupation', 
                       'HouseOwnerFlag', 'NumberCarsOwned', 'AddressLine1', 'AddressLine2', 
                       'Phone', 'DateFirstPurchase']]

# %%
result.sort_values(by='CustomerKey', inplace=True)
result
# Out:
#        CustomerKey  GeographyKey CustomerAlternateKey Title  FirstName  \
# 11250        11000            26           AW00011000  None        Jon
# 3164         11001            37           AW00011001  None     Eugene
# 8987         11002            31           AW00011002  None      Ruben
# 9076         11003            11           AW00011003  None    Christy
# 9620         11004            19           AW00011004  None  Elizabeth
# ...            ...           ...                  ...   ...        ...
# 1899         29479           145           AW00029479  None      Tommy
# 2181         29480           251           AW00029480  None       Nina
# 5882         29481           169           AW00029481  None       Ivan
# 10289        29482           114           AW00029482  None    Clayton
# 16109        29483           153           AW00029483  None      Jésus
#
#       MiddleName LastName  NameStyle  BirthDate MaritalStatus  ...  \
# 11250          V     Yang      False 1966-04-08             M  ...
# 3164           L    Huang      False 1965-05-14             S  ...
# 8987        None   Torres      False 1965-08-12             M  ...
# 9076        None      Zhu      False 1968-02-15             S  ...
# 9620        None  Johnson      False 1968-08-08             S  ...
# ...          ...      ...        ...        ...           ...  ...
# 1899           L     Tang      False 1958-07-04             M  ...
# 2181           W     Raji      False 1960-11-10             S  ...
# 5882        None     Suri      False 1960-01-05             S  ...
# 10289       None    Zhang      False 1959-03-05             M  ...
# 16109          L  Navarro      False 1959-12-08             M  ...
#
#       TotalChildren NumberChildrenAtHome EnglishEducation EnglishOccupation  \
# 11250           2.0                  0.0       Bachelors       Professional
# 3164            3.0                  3.0       Bachelors       Professional
# 8987            3.0                  3.0       Bachelors       Professional
# 9076            0.0                  0.0       Bachelors       Professional
# 9620            5.0                  5.0       Bachelors       Professional
# ...             ...                  ...              ...               ...
# 1899            1.0                  0.0  Graduate Degree          Clerical
# 2181            3.0                  0.0  Graduate Degree          Clerical
# 5882            3.0                  0.0  Graduate Degree          Clerical
# 10289           3.0                  0.0       Bachelors           Clerical
# 16109           0.0                  0.0       Bachelors           Clerical
#
#        HouseOwnerFlag  NumberCarsOwned               AddressLine1  \
# 11250            True              0.0            3761 N. 14th St
# 3164            False              1.0                 2243 W St.
# 8987             True              1.0           5844 Linden Land
# 9076            False              1.0           1825 Village Pl.
# 9620             True              4.0        7553 Harness Circle
# ...               ...              ...                        ...
# 1899             True              0.0          111, rue Maillard
# 2181             True              0.0          9 Katherine Drive
# 5882            False              0.0                Knaackstr 4
# 10289            True              0.0     1080, quai de Grenelle
# 16109            True              0.0  244, rue de la Centenaire
#
#       AddressLine2                Phone  DateFirstPurchase
# 11250         None  1 (11) 500 555-0162         2001-07-22
# 3164          None  1 (11) 500 555-0110         2001-07-18
# 8987          None  1 (11) 500 555-0184         2001-07-10
# 9076          None  1 (11) 500 555-0162         2001-07-01
# 9620          None  1 (11) 500 555-0131         2001-07-26
# ...            ...                  ...                ...
# 1899          None  1 (11) 500 555-0136         2003-03-08
# 2181          None  1 (11) 500 555-0146         2004-01-18
# 5882          None  1 (11) 500 555-0144         2002-02-13
# 10289         None  1 (11) 500 555-0137         2003-03-22
# 16109         None  1 (11) 500 555-0141         2003-03-13
#
# [18484 rows x 24 columns]

# %% [markdown]
# ## LOAD

# %%
# Commute Distance column is still missing!!
db_op, db_etl = connect_databases()
result.to_sql('DimCustomer', db_etl, if_exists='replace', index=False)
# Out:
# 484

# %%
test = pd.read_sql_query('SELECT * FROM "DimCustomer"', db_etl)
test
# Out:
#        CustomerKey  GeographyKey CustomerAlternateKey Title  FirstName  \
# 0            11000            26           AW00011000  None        Jon
# 1            11001            37           AW00011001  None     Eugene
# 2            11002            31           AW00011002  None      Ruben
# 3            11003            11           AW00011003  None    Christy
# 4            11004            19           AW00011004  None  Elizabeth
# ...            ...           ...                  ...   ...        ...
# 18479        29479           145           AW00029479  None      Tommy
# 18480        29480           251           AW00029480  None       Nina
# 18481        29481           169           AW00029481  None       Ivan
# 18482        29482           114           AW00029482  None    Clayton
# 18483        29483           153           AW00029483  None      Jésus
#
#       MiddleName LastName  NameStyle  BirthDate MaritalStatus  ...  \
# 0              V     Yang      False 1966-04-08             M  ...
# 1              L    Huang      False 1965-05-14             S  ...
# 2           None   Torres      False 1965-08-12             M  ...
# 3           None      Zhu      False 1968-02-15             S  ...
# 4           None  Johnson      False 1968-08-08             S  ...
# ...          ...      ...        ...        ...           ...  ...
# 18479          L     Tang      False 1958-07-04             M  ...
# 18480          W     Raji      False 1960-11-10             S  ...
# 18481       None     Suri      False 1960-01-05             S  ...
# 18482       None    Zhang      False 1959-03-05             M  ...
# 18483          L  Navarro      False 1959-12-08             M  ...
#
#       TotalChildren NumberChildrenAtHome EnglishEducation EnglishOccupation  \
# 0               2.0                  0.0       Bachelors       Professional
# 1               3.0                  3.0       Bachelors       Professional
# 2               3.0                  3.0       Bachelors       Professional
# 3               0.0                  0.0       Bachelors       Professional
# 4               5.0                  5.0       Bachelors       Professional
# ...             ...                  ...              ...               ...
# 18479           1.0                  0.0  Graduate Degree          Clerical
# 18480           3.0                  0.0  Graduate Degree          Clerical
# 18481           3.0                  0.0  Graduate Degree          Clerical
# 18482           3.0                  0.0       Bachelors           Clerical
# 18483           0.0                  0.0       Bachelors           Clerical
#
#        HouseOwnerFlag  NumberCarsOwned               AddressLine1  \
# 0                True              0.0            3761 N. 14th St
# 1               False              1.0                 2243 W St.
# 2                True              1.0           5844 Linden Land
# 3               False              1.0           1825 Village Pl.
# 4                True              4.0        7553 Harness Circle
# ...               ...              ...                        ...
# 18479            True              0.0          111, rue Maillard
# 18480            True              0.0          9 Katherine Drive
# 18481           False              0.0                Knaackstr 4
# 18482            True              0.0     1080, quai de Grenelle
# 18483            True              0.0  244, rue de la Centenaire
#
#       AddressLine2                Phone  DateFirstPurchase
# 0             None  1 (11) 500 555-0162         2001-07-22
# 1             None  1 (11) 500 555-0110         2001-07-18
# 2             None  1 (11) 500 555-0184         2001-07-10
# 3             None  1 (11) 500 555-0162         2001-07-01
# 4             None  1 (11) 500 555-0131         2001-07-26
# ...            ...                  ...                ...
# 18479         None  1 (11) 500 555-0136         2003-03-08
# 18480         None  1 (11) 500 555-0146         2004-01-18
# 18481         None  1 (11) 500 555-0144         2002-02-13
# 18482         None  1 (11) 500 555-0137         2003-03-22
# 18483         None  1 (11) 500 555-0141         2003-03-13
#
# [18484 rows x 24 columns]
