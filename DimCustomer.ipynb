# %% [markdown]
# # CUSTOMER DIMENSION

# %%
import pandas as pd
from connection_script import connect_databases

# %%
db_op, db_etl = connect_databases()

# %% [markdown]
# ## EXTRACT

# %%
# Load the required tables into pandas DataFrames
individual_customer = pd.read_sql_query('SELECT * FROM [Sales].[vIndividualCustomer]', db_op)
person = pd.read_sql_query('SELECT * FROM [Person].[Person]', db_op)
person_phone = pd.read_sql_query('SELECT * FROM [Person].[PersonPhone]', db_op)
person_demographics = pd.read_sql_query('SELECT * FROM [Sales].[vPersonDemographics]', db_op)
dim_geography = pd.read_sql_query('SELECT * FROM public."DimGeography"', db_etl)

# Merge the DataFrames
merged_df = individual_customer.merge(person, left_on='BusinessEntityID', right_on='BusinessEntityID')
merged_df = merged_df.merge(person_phone, left_on='BusinessEntityID', right_on='BusinessEntityID')
merged_df = merged_df.merge(person_demographics, left_on='BusinessEntityID', right_on='BusinessEntityID')
merged_df = merged_df.merge(dim_geography, left_on='City', right_on='City')

# Select the desired columns
result = merged_df[['BusinessEntityID','GeographyKey', 'Title_x','FirstName_x', 'MiddleName_x', 'LastName_x', 'NameStyle', 'BirthDate', 'MaritalStatus', 'Suffix_x', 'Gender',
                    'EmailAddress', 'YearlyIncome', 'TotalChildren', 'NumberChildrenAtHome', 'Education',
                    'Occupation', 'HomeOwnerFlag', 'NumberCarsOwned', 'AddressLine1', 'AddressLine2',
                    'PhoneNumber_x', 'DateFirstPurchase']]

result
# Out:
#        BusinessEntityID  GeographyKey Title_x FirstName_x MiddleName_x  \
# 0                  1699           210     Mr.       David           R.
# 1                  1700            37     Ms.     Rebecca           A.
# 2                  1701            34     Ms.     Dorothy           B.
# 3                  1702           244     Ms.   Carol Ann           F.
# 4                  1703            22     Mr.       Scott           M.
# ...                 ...           ...     ...         ...          ...
# 34674             20773           272    None     Crystal         None
# 34675             20774           380    None    Isabella            F
# 34676             20775           633    None     Crystal            S
# 34677             20776           145    None     Crystal         None
# 34678             20777             3    None     Crystal         None
#
#        LastName_x  NameStyle  BirthDate MaritalStatus Suffix_x  ...  \
# 0        Robinett      False 1961-02-23             M     None  ...
# 1        Robinson      False 1965-06-11             M     None  ...
# 2        Robinson      False 1954-09-23             S     None  ...
# 3          Rockne      False 1943-07-15             M     None  ...
# 4         Rodgers      False 1968-05-15             M     None  ...
# ...           ...        ...        ...           ...      ...  ...
# 34674         Guo      False 1974-11-23             S     None  ...
# 34675  Richardson      False 1961-06-12             M     None  ...
# 34676          He      False 1940-04-05             M     None  ...
# 34677       Zheng      False 1975-07-25             S     None  ...
# 34678          Hu      False 1971-05-05             M     None  ...
#
#       TotalChildren NumberChildrenAtHome            Education      Occupation  \
# 0               4.0                  0.0      Graduate Degree        Clerical
# 1               3.0                  3.0           Bachelors     Professional
# 2               2.0                  0.0      Partial College  Skilled Manual
# 3               1.0                  0.0           Bachelors         Clerical
# 4               2.0                  2.0           Bachelors     Professional
# ...             ...                  ...                  ...             ...
# 34674           0.0                  0.0  Partial High School          Manual
# 34675           1.0                  0.0      Partial College  Skilled Manual
# 34676           3.0                  0.0           Bachelors       Management
# 34677           0.0                  0.0      Partial College        Clerical
# 34678           0.0                  0.0           Bachelors     Professional
#
#        HomeOwnerFlag NumberCarsOwned            AddressLine1 AddressLine2  \
# 0               True             0.0        Pappelallee 6667         None
# 1               True             1.0      1861 Chinquapin Ct         None
# 2              False             2.0          4693 Mills Dr.         None
# 3               True             0.0     1312 Skycrest Drive         None
# 4               True             1.0    9860 Brookview Drive         None
# ...              ...             ...                     ...          ...
# 34674           True             2.0   988 Mt. Everest Court         None
# 34675           True             1.0       7413 Alpine Drive         None
# 34676           True             2.0        4764 East Avenue         None
# 34677           True             1.0  34334, rue Jean Mermoz         None
# 34678          False             4.0       6022 La Salle Ct.         None
#
#              PhoneNumber_x DateFirstPurchase
# 0             238-555-0100        2003-09-01
# 1             648-555-0100        2004-06-05
# 2             423-555-0100        2002-04-07
# 3             439-555-0100        2001-10-27
# 4             989-555-0100        2002-04-18
# ...                    ...               ...
# 34674  1 (11) 500 555-0171        2004-04-19
# 34675         910-555-0166        2003-08-30
# 34676         813-555-0148        2004-04-12
# 34677  1 (11) 500 555-0171        2004-02-15
# 34678  1 (11) 500 555-0126        2003-11-17
#
# [34679 rows x 23 columns]

# %%
len(result)
# Out:
# 34679

# %% [markdown]
# ## TRANSFORM

# %%
result = result.drop_duplicates(subset=['BusinessEntityID'])

# %%
# Rename columns
result = result.rename(columns={'Education':'EnglishEducation', 'Occupation':'EnglishOccupation', 'HomeOwnerFlag':'HouseOwnerFlag'})

# %%
result = result.rename(columns={
    'Title_x': 'Title',
    'FirstName_x': 'FirstName',
    'MiddleName_x': 'MiddleName',
    'LastName_x': 'LastName',
    'Suffix_x': 'Suffix',
    'PhoneNumber_x': 'Phone',
    'Education':'EnglishEducation',
    'Occupation':'EnglishOccupation',
    'HomeOwnerFlag':'HouseOwnerFlag'
})

# %%
result = result.reset_index()
result.index += 11000

# %%
def generateAlternateKey(ind):
    l = len(str(ind))
    zeros = 8 - l
    alternateKey = 'AW' + '0'*zeros + str(ind)
    return alternateKey

# %%
#result['CustomerAlternateKey'] = list(result.index)
#result['CustomerAlternateKey'] = result['CustomerAlternateKey'].apply(lambda x: generateAlternateKey(x))
result = result.assign(CustomerAlternateKey=list(result.index))
result['CustomerAlternateKey'] = result['CustomerAlternateKey'].apply(lambda x: generateAlternateKey(x))

# %%
result = result[['GeographyKey', 'CustomerAlternateKey','Title', 'FirstName', 'MiddleName', 'LastName', 'NameStyle', 'BirthDate', 
                       'MaritalStatus', 'Suffix', 'Gender', 'EmailAddress', 'YearlyIncome', 
                       'TotalChildren', 'NumberChildrenAtHome', 'EnglishEducation', 'EnglishOccupation', 
                       'HouseOwnerFlag', 'NumberCarsOwned', 'AddressLine1', 'AddressLine2', 
                       'Phone', 'DateFirstPurchase']]

# %%
result
# Out:
#        GeographyKey CustomerAlternateKey Title  FirstName MiddleName  \
# 11000           210           AW00011000   Mr.      David         R.
# 11001            37           AW00011001   Ms.    Rebecca         A.
# 11002            34           AW00011002   Ms.    Dorothy         B.
# 11003           244           AW00011003   Ms.  Carol Ann         F.
# 11004            22           AW00011004   Mr.      Scott         M.
# ...             ...                  ...   ...        ...        ...
# 29479           272           AW00029479  None    Crystal       None
# 29480           380           AW00029480  None   Isabella          F
# 29481           633           AW00029481  None    Crystal          S
# 29482           145           AW00029482  None    Crystal       None
# 29483             3           AW00029483  None    Crystal       None
#
#          LastName  NameStyle  BirthDate MaritalStatus Suffix  ...  \
# 11000    Robinett      False 1961-02-23             M   None  ...
# 11001    Robinson      False 1965-06-11             M   None  ...
# 11002    Robinson      False 1954-09-23             S   None  ...
# 11003      Rockne      False 1943-07-15             M   None  ...
# 11004     Rodgers      False 1968-05-15             M   None  ...
# ...           ...        ...        ...           ...    ...  ...
# 29479         Guo      False 1974-11-23             S   None  ...
# 29480  Richardson      False 1961-06-12             M   None  ...
# 29481          He      False 1940-04-05             M   None  ...
# 29482       Zheng      False 1975-07-25             S   None  ...
# 29483          Hu      False 1971-05-05             M   None  ...
#
#       TotalChildren NumberChildrenAtHome     EnglishEducation  \
# 11000           4.0                  0.0      Graduate Degree
# 11001           3.0                  3.0           Bachelors
# 11002           2.0                  0.0      Partial College
# 11003           1.0                  0.0           Bachelors
# 11004           2.0                  2.0           Bachelors
# ...             ...                  ...                  ...
# 29479           0.0                  0.0  Partial High School
# 29480           1.0                  0.0      Partial College
# 29481           3.0                  0.0           Bachelors
# 29482           0.0                  0.0      Partial College
# 29483           0.0                  0.0           Bachelors
#
#        EnglishOccupation  HouseOwnerFlag NumberCarsOwned  \
# 11000           Clerical            True             0.0
# 11001       Professional            True             1.0
# 11002     Skilled Manual           False             2.0
# 11003           Clerical            True             0.0
# 11004       Professional            True             1.0
# ...                  ...             ...             ...
# 29479             Manual            True             2.0
# 29480     Skilled Manual            True             1.0
# 29481         Management            True             2.0
# 29482           Clerical            True             1.0
# 29483       Professional           False             4.0
#
#                  AddressLine1 AddressLine2                Phone  \
# 11000        Pappelallee 6667         None         238-555-0100
# 11001      1861 Chinquapin Ct         None         648-555-0100
# 11002          4693 Mills Dr.         None         423-555-0100
# 11003     1312 Skycrest Drive         None         439-555-0100
# 11004    9860 Brookview Drive         None         989-555-0100
# ...                       ...          ...                  ...
# 29479   988 Mt. Everest Court         None  1 (11) 500 555-0171
# 29480       7413 Alpine Drive         None         910-555-0166
# 29481        4764 East Avenue         None         813-555-0148
# 29482  34334, rue Jean Mermoz         None  1 (11) 500 555-0171
# 29483       6022 La Salle Ct.         None  1 (11) 500 555-0126
#
#       DateFirstPurchase
# 11000        2003-09-01
# 11001        2004-06-05
# 11002        2002-04-07
# 11003        2001-10-27
# 11004        2002-04-18
# ...                 ...
# 29479        2004-04-19
# 29480        2003-08-30
# 29481        2004-04-12
# 29482        2004-02-15
# 29483        2003-11-17
#
# [18484 rows x 23 columns]

# %%
#geography_key_backup = list(result['GeographyKey'])
#result = result.drop(columns=['GeographyKey'])
#result

# %%
#result = result.assign(GeographyKey=geography_key_backup)
#result

# %% [markdown]
# ## LOAD

# %%
# Commute Distance column is still missing!!
db_op, db_etl = connect_databases()
result.to_sql('DimCustomer', db_etl, if_exists='replace', index_label='CustomerKey')
# Out:
# 484
